# %%
pip install PyYAML
# Out:
# Requirement already satisfied: PyYAML in c:\users\rajwn\downloads\beverage\yolo_venv\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import os
import yaml
from yaml.loader import SafeLoader

# %%
##Loading yaml file
with open('data.yaml', mode='r') as f:
    data_yaml= yaml.load(f, Loader=SafeLoader)

labels = data_yaml['names']
print(labels)
# Out:
# ['person', 'car', 'chair', 'bottle', 'pottedplant', 'bird', 'dog', 'sofa', 'bicycle', 'horse', 'boat', 'motorbike', 'cat', 'tvmonitor', 'cow', 'sheep', 'aeroplane', 'train', 'diningtable', 'bus']

# %%
# Load Yolo Model
yolo = cv2.dnn.readNetFromONNX('./Model/weights/best.onnx')
yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)

# %%
# Load the test image to get prediction
img = cv2.imread('./street_image.jpg')
image = img.copy()
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#row: width of image; col: height of image; d : color
row, col, d = image.shape

max_rc = max(row,col)
input_image = np.zeros((max_rc,max_rc,3),dtype=np.uint8)
cv2.imshow('input_image',input_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# get the yolo prediction from the image


#converting image into square array
row, col, d = image.shape
max_rc = max(row,col)
input_image = np.zeros((max_rc,max_rc,3),dtype=np.uint8)
input_image[0:row, 0:col] = image



#get prediction from square array
INPUT_WH_YOLO = 640
blob = cv2.dnn.blobFromImage(input_image,1/255,(INPUT_WH_YOLO,INPUT_WH_YOLO),swapRB=True,crop=False)
yolo.setInput(blob)
preds = yolo.forward()


print(preds.shape)
#25200 : bounding boxes; 25 columns : centre x,centre y,W,H,Confidence,  probscore class1, ....probscoreclass20
# Out:
# (1, 25200, 25)

# %%
# Non-Maximum Supression (To get away with multiple bounding boxes)

#step1: filter detection based on confidence(0.4) and probability score(0.25)
detections = preds[0]
boxes = []
confidences = []
classes = []


# width and height of the image (input_image)
image_w, image_h = input_image.shape[:2]
x_factor = image_w/INPUT_WH_YOLO
y_factor = image_h/INPUT_WH_YOLO


for i in range (len(detections)):
    row = detections[i]
    confidence = row[4]
    if confidence > 0.4:
         class_score = row[5:].max() #maximum probability from objects
         class_id = row[5:].argmax()# index position at max prob

         if class_score > 0.25:
              cx, cy, w, h = row[0:4]
              # construct bounding from four values
              # left, top, width, height
              left = int((cx - 0.5*w)*x_factor)
              top = int((cy - 0.5*h)*y_factor)
              width = int(w*x_factor)
              height = int(h*y_factor)

              box = np.array([left,top,width,height])

              confidences.append(confidence)
              boxes.append(box)
              classes.append(class_id)

# %%
confidences
# Out:
# [np.float32(0.48257402),
#  np.float32(0.53962845),
#  np.float32(0.54132277),
#  np.float32(0.44483432),
#  np.float32(0.4479569),
#  np.float32(0.60229576),
#  np.float32(0.70132756),
#  np.float32(0.45455986),
#  np.float32(0.47489694),
#  np.float32(0.49938738),
#  np.float32(0.45838055),
#  np.float32(0.6622501),
#  np.float32(0.7678153),
#  np.float32(0.5696365),
#  np.float32(0.73180085),
#  np.float32(0.67971927),
#  np.float32(0.6272745),
#  np.float32(0.5302333),
#  np.float32(0.5125046),
#  np.float32(0.48839337),
#  np.float32(0.42139658),
#  np.float32(0.45473224),
#  np.float32(0.5198604),
#  np.float32(0.4392945),
#  np.float32(0.51502156),
#  np.float32(0.5927299),
#  np.float32(0.61433893),
#  np.float32(0.59259903),
#  np.float32(0.42723718),
#  np.float32(0.53011),
#  np.float32(0.42107236),
#  np.float32(0.6025764),
#  np.float32(0.75373137),
#  np.float32(0.40664852),
#  np.float32(0.5030193),
#  np.float32(0.46019152),
#  np.float32(0.4185531),
#  np.float32(0.40155166),
#  np.float32(0.88447493),
#  np.float32(0.8723721),
#  np.float32(0.47517744),
#  np.float32(0.6436827),
#  np.float32(0.44845846),
#  np.float32(0.40345815),
#  np.float32(0.44708812),
#  np.float32(0.47364938),
#  np.float32(0.56946737),
#  np.float32(0.64008623),
#  np.float32(0.7973364),
#  np.float32(0.4619816),
#  np.float32(0.6593366),
#  np.float32(0.61339116),
#  np.float32(0.5793987),
#  np.float32(0.5706668),
#  np.float32(0.46919876),
#  np.float32(0.6241819),
#  np.float32(0.40952253),
#  np.float32(0.43603227),
#  np.float32(0.56591815),
#  np.float32(0.44167876),
#  np.float32(0.5818233),
#  np.float32(0.5019498),
#  np.float32(0.8364806),
#  np.float32(0.6403559),
#  np.float32(0.45359734),
#  np.float32(0.5298926),
#  np.float32(0.40558589),
#  np.float32(0.48048106),
#  np.float32(0.6436886),
#  np.float32(0.7770728),
#  np.float32(0.41151518),
#  np.float32(0.5194858),
#  np.float32(0.5795408),
#  np.float32(0.43271184),
#  np.float32(0.75725526),
#  np.float32(0.6548744),
#  np.float32(0.41866335),
#  np.float32(0.40632057),
#  np.float32(0.61971223),
#  np.float32(0.51954526),
#  np.float32(0.7623021),
#  np.float32(0.74047494),
#  np.float32(0.84404457),
#  np.float32(0.5531546),
#  np.float32(0.63827384),
#  np.float32(0.45701426),
#  np.float32(0.5983587),
#  np.float32(0.7097198),
#  np.float32(0.67777705),
#  np.float32(0.4396657),
#  np.float32(0.4156394),
#  np.float32(0.43943346),
#  np.float32(0.6494576),
#  np.float32(0.46859613),
#  np.float32(0.73153657),
#  np.float32(0.57036114),
#  np.float32(0.65588576),
#  np.float32(0.65875953),
#  np.float32(0.5256658),
#  np.float32(0.5329564),
#  np.float32(0.49095458),
#  np.float32(0.553627),
#  np.float32(0.6924357),
#  np.float32(0.50549495),
#  np.float32(0.6622865),
#  np.float32(0.42043066),
#  np.float32(0.70753163),
#  np.float32(0.8550478),
#  np.float32(0.8104654),
#  np.float32(0.7977601),
#  np.float32(0.770586),
#  np.float32(0.57541686),
#  np.float32(0.4088372),
#  np.float32(0.5446219),
#  np.float32(0.40184975),
#  np.float32(0.6890265),
#  np.float32(0.68081933),
#  np.float32(0.47648662),
#  np.float32(0.7387762),
#  np.float32(0.5438656),
#  np.float32(0.7419589),
#  np.float32(0.6268219),
#  np.float32(0.7518541),
#  np.float32(0.6560815),
#  np.float32(0.7716341),
#  np.float32(0.6414721),
#  np.float32(0.401228),
#  np.float32(0.5673092),
#  np.float32(0.49762157),
#  np.float32(0.69782245),
#  np.float32(0.55015504),
#  np.float32(0.6782297),
#  np.float32(0.59589326),
#  np.float32(0.451835),
#  np.float32(0.63574004),
#  np.float32(0.49792182),
#  np.float32(0.8250965),
#  np.float32(0.72164637),
#  np.float32(0.7747109),
#  np.float32(0.5593978),
#  np.float32(0.68470407),
#  np.float32(0.4456836),
#  np.float32(0.6704357),
#  np.float32(0.75326383),
#  np.float32(0.40187585),
#  np.float32(0.73864615),
#  np.float32(0.6879966),
#  np.float32(0.65415055),
#  np.float32(0.64235544),
#  np.float32(0.4411717),
#  np.float32(0.68117136),
#  np.float32(0.47449398),
#  np.float32(0.6464169),
#  np.float32(0.5812785),
#  np.float32(0.527918),
#  np.float32(0.52865523),
#  np.float32(0.5154344),
#  np.float32(0.68304247),
#  np.float32(0.4901778),
#  np.float32(0.5761834),
#  np.float32(0.70237887),
#  np.float32(0.8822808),
#  np.float32(0.8257893),
#  np.float32(0.8225795),
#  np.float32(0.74907446),
#  np.float32(0.6381285),
#  np.float32(0.42375678),
#  np.float32(0.62288296),
#  np.float32(0.6955419),
#  np.float32(0.6890046),
#  np.float32(0.41089097),
#  np.float32(0.6651417),
#  np.float32(0.55089945),
#  np.float32(0.6581135),
#  np.float32(0.6216431),
#  np.float32(0.7471499),
#  np.float32(0.697742),
#  np.float32(0.76655),
#  np.float32(0.6613654),
#  np.float32(0.43272755),
#  np.float32(0.49188662),
#  np.float32(0.7738237),
#  np.float32(0.586068),
#  np.float32(0.57863885),
#  np.float32(0.59651536),
#  np.float32(0.76211023),
#  np.float32(0.70474213),
#  np.float32(0.45142627),
#  np.float32(0.55787027),
#  np.float32(0.67181605),
#  np.float32(0.8020253),
#  np.float32(0.61525804),
#  np.float32(0.50285935),
#  np.float32(0.48169693),
#  np.float32(0.519089),
#  np.float32(0.68369526),
#  np.float32(0.79554784),
#  np.float32(0.83232796),
#  np.float32(0.41956472),
#  np.float32(0.5281855),
#  np.float32(0.5320607),
#  np.float32(0.56096065),
#  np.float32(0.62443614),
#  np.float32(0.70083183),
#  np.float32(0.7304374),
#  np.float32(0.4763025),
#  np.float32(0.43503994),
#  np.float32(0.6174982),
#  np.float32(0.43051824),
#  np.float32(0.6732466),
#  np.float32(0.5509403),
#  np.float32(0.4884329),
#  np.float32(0.4914701),
#  np.float32(0.5538598),
#  np.float32(0.6760771),
#  np.float32(0.52842003),
#  np.float32(0.60144395),
#  np.float32(0.43854296),
#  np.float32(0.65462816),
#  np.float32(0.42684004),
#  np.float32(0.85938615),
#  np.float32(0.78501666),
#  np.float32(0.8032765),
#  np.float32(0.7449028),
#  np.float32(0.5963791),
#  np.float32(0.43110675),
#  np.float32(0.58089995),
#  np.float32(0.6233632),
#  np.float32(0.45331657),
#  np.float32(0.6630028),
#  np.float32(0.5224577),
#  np.float32(0.70285106),
#  np.float32(0.6165508),
#  np.float32(0.7603517),
#  np.float32(0.65427685),
#  np.float32(0.7368106),
#  np.float32(0.6136738),
#  np.float32(0.41200885),
#  np.float32(0.76138663),
#  np.float32(0.55191153),
#  np.float32(0.55866843),
#  np.float32(0.61372864),
#  np.float32(0.75768787),
#  np.float32(0.647468),
#  np.float32(0.4059255),
#  np.float32(0.66212744),
#  np.float32(0.6781478),
#  np.float32(0.78014296),
#  np.float32(0.6019101),
#  np.float32(0.46656373),
#  np.float32(0.6095408),
#  np.float32(0.59611356),
#  np.float32(0.47299644),
#  np.float32(0.53583866),
#  np.float32(0.7824543),
#  np.float32(0.81508726),
#  np.float32(0.49355114),
#  np.float32(0.6568118),
#  np.float32(0.4927111),
#  np.float32(0.82179666),
#  np.float32(0.5395524),
#  np.float32(0.5934236),
#  np.float32(0.7772622),
#  np.float32(0.48472047),
#  np.float32(0.54424316),
#  np.float32(0.823605),
#  np.float32(0.8724902),
#  np.float32(0.5859963),
#  np.float32(0.73062533),
#  np.float32(0.48301637),
#  np.float32(0.53528184),
#  np.float32(0.5101633),
#  np.float32(0.58954453),
#  np.float32(0.44534436),
#  np.float32(0.4171281),
#  np.float32(0.55247486),
#  np.float32(0.46471378),
#  np.float32(0.66592884),
#  np.float32(0.40925258),
#  np.float32(0.6664259),
#  np.float32(0.5523453),
#  np.float32(0.4976901),
#  np.float32(0.48165336),
#  np.float32(0.41241577),
#  np.float32(0.54252166),
#  np.float32(0.76909214),
#  np.float32(0.72166884),
#  np.float32(0.7434417),
#  np.float32(0.80610126),
#  np.float32(0.80127907),
#  np.float32(0.5774899),
#  np.float32(0.7356665),
#  np.float32(0.8312637),
#  np.float32(0.84004486),
#  np.float32(0.58929795),
#  np.float32(0.62205565),
#  np.float32(0.6892842),
#  np.float32(0.4572328),
#  np.float32(0.4180977),
#  np.float32(0.7190183),
#  np.float32(0.5146033),
#  np.float32(0.73587507),
#  np.float32(0.60965014),
#  np.float32(0.5953191),
#  np.float32(0.55009),
#  np.float32(0.7594785),
#  np.float32(0.68915755),
#  np.float32(0.7939875),
#  np.float32(0.51098526),
#  np.float32(0.72281927)]

# %%
boxes
# Out:
# [array([874, 423, 103, 106]),
#  array([1763,  532,   62,   97]),
#  array([1615,  710,   97,   80]),
#  array([762, 352, 129,  98]),
#  array([626, 413, 135, 114]),
#  array([643, 417, 115, 108]),
#  array([871, 418, 114, 116]),
#  array([872, 416, 116, 118]),
#  array([869, 425, 119, 103]),
#  array([661, 470, 146, 122]),
#  array([1760,  529,   64,  101]),
#  array([285, 620,  62, 190]),
#  array([284, 624,  62, 183]),
#  array([1880,  613,   41,  205]),
#  array([175, 613,  82, 256]),
#  array([180, 609,  88, 248]),
#  array([203, 614,  69, 223]),
#  array([284, 627,  61, 178]),
#  array([373, 642,  75, 184]),
#  array([1615,  709,   97,   82]),
#  array([1712,  680,   83,  111]),
#  array([1706,  678,  126,  117]),
#  array([1730,  677,  107,  123]),
#  array([118, 660,  73, 217]),
#  array([168, 623,  84, 241]),
#  array([366, 641,  84, 222]),
#  array([364, 640,  83, 222]),
#  array([828, 669, 103, 208]),
#  array([1617,  705,   92,   87]),
#  array([1614,  706,   96,   80]),
#  array([1716,  679,  129,  124]),
#  array([118, 666,  74, 211]),
#  array([824, 663, 108, 211]),
#  array([1035,  646,  155,  285]),
#  array([1036,  638,  159,  322]),
#  array([1213,  671,  122,  256]),
#  array([761, 351, 182,  96]),
#  array([763, 352, 215,  93]),
#  array([1022,  332,  254,  222]),
#  array([1017,  337,  267,  219]),
#  array([643, 419, 115, 107]),
#  array([873, 418, 111, 117]),
#  array([872, 416, 118, 118]),
#  array([773, 444, 139, 120]),
#  array([662, 472, 146, 122]),
#  array([1760,  530,   63,  101]),
#  array([1576,  576,  269,  120]),
#  array([288, 622,  58, 187]),
#  array([287, 627,  57, 178]),
#  array([1882,  616,   37,  201]),
#  array([180, 617,  74, 252]),
#  array([183, 611,  83, 246]),
#  array([206, 615,  64, 225]),
#  array([286, 632,  59, 171]),
#  array([375, 642,  72, 185]),
#  array([947, 649, 191, 179]),
#  array([945, 644, 219, 185]),
#  array([1708,  679,  121,  116]),
#  array([1735,  678,   99,  123]),
#  array([170, 625,  79, 240]),
#  array([368, 641,  81, 222]),
#  array([365, 641,  82, 222]),
#  array([501, 644, 302, 218]),
#  array([831, 669,  96, 208]),
#  array([949, 651, 180, 182]),
#  array([1615,  709,   94,   77]),
#  array([1703,  688,  126,  105]),
#  array([1715,  680,  127,  125]),
#  array([122, 670,  71, 208]),
#  array([825, 665, 107, 211]),
#  array([369, 763, 352, 189]),
#  array([380, 760, 362, 195]),
#  array([1239,  756,  323,  202]),
#  array([755, 345, 174, 106]),
#  array([759, 347, 198, 100]),
#  array([750, 346, 218, 104]),
#  array([1011,  333,  265,  224]),
#  array([613, 397, 141, 128]),
#  array([620, 399, 139, 126]),
#  array([869, 410, 115, 122]),
#  array([870, 412, 119, 120]),
#  array([1014,  329,  270,  225]),
#  array([1016,  332,  266,  226]),
#  array([637, 416, 129, 118]),
#  array([661, 462, 148, 130]),
#  array([681, 451, 229, 125]),
#  array([766, 442, 142, 119]),
#  array([869, 419, 119, 111]),
#  array([664, 469, 140, 126]),
#  array([1756,  519,   75,  111]),
#  array([1211,  442,  327,  317]),
#  array([1220,  443,  325,  319]),
#  array([1575,  572,  263,  114]),
#  array([1759,  524,   71,  101]),
#  array([1582,  575,  262,  121]),
#  array([1589,  575,  256,  121]),
#  array([179, 608,  91, 242]),
#  array([286, 622,  65, 181]),
#  array([288, 614,  58, 191]),
#  array([944, 639, 190, 195]),
#  array([1705,  675,  111,  116]),
#  array([114, 667,  84, 200]),
#  array([172, 612,  91, 246]),
#  array([185, 614,  87, 232]),
#  array([286, 624,  61, 184]),
#  array([363, 647,  76, 214]),
#  array([364, 641,  82, 212]),
#  array([515, 649, 288, 215]),
#  array([519, 648, 283, 220]),
#  array([827, 664,  98, 215]),
#  array([946, 644, 185, 181]),
#  array([950, 641, 194, 190]),
#  array([1221,  682,  113,  179]),
#  array([1613,  705,  102,   82]),
#  array([1615,  704,   99,   83]),
#  array([1708,  679,  124,  116]),
#  array([1704,  670,  133,  130]),
#  array([119, 681,  69, 198]),
#  array([117, 671,  70, 209]),
#  array([361, 644,  84, 219]),
#  array([518, 651, 286, 206]),
#  array([827, 674,  99, 208]),
#  array([826, 668, 101, 208]),
#  array([1037,  647,  156,  303]),
#  array([1035,  647,  155,  303]),
#  array([1219,  687,  118,  200]),
#  array([1619,  711,   80,   72]),
#  array([1039,  652,  149,  301]),
#  array([1248,  749,  305,  211]),
#  array([1249,  750,  308,  213]),
#  array([1247,  756,  305,  202]),
#  array([757, 350, 204,  99]),
#  array([751, 348, 219, 100]),
#  array([1013,  331,  259,  227]),
#  array([619, 399, 140, 123]),
#  array([868, 408, 119, 124]),
#  array([869, 413, 119, 119]),
#  array([1012,  329,  273,  230]),
#  array([1017,  334,  262,  228]),
#  array([638, 417, 130, 114]),
#  array([664, 464, 145, 124]),
#  array([679, 450, 228, 122]),
#  array([770, 447, 143, 116]),
#  array([869, 417, 120, 111]),
#  array([664, 479, 143, 121]),
#  array([662, 472, 144, 123]),
#  array([1209,  440,  348,  324]),
#  array([1205,  441,  353,  323]),
#  array([1578,  572,  253,  112]),
#  array([1759,  522,   73,  105]),
#  array([1584,  575,  259,  120]),
#  array([1593,  579,  248,  121]),
#  array([182, 611,  86, 237]),
#  array([284, 619,  68, 182]),
#  array([947, 645, 187, 182]),
#  array([1704,  676,  113,  117]),
#  array([114, 664,  84, 202]),
#  array([174, 611,  91, 246]),
#  array([185, 607,  86, 235]),
#  array([285, 619,  68, 188]),
#  array([365, 641,  84, 213]),
#  array([517, 650, 287, 208]),
#  array([522, 652, 279, 209]),
#  array([829, 662, 101, 215]),
#  array([944, 647, 190, 180]),
#  array([953, 647, 190, 184]),
#  array([1224,  681,  110,  178]),
#  array([1614,  706,  101,   83]),
#  array([1709,  678,  127,  116]),
#  array([1703,  671,  132,  130]),
#  array([119, 676,  69, 204]),
#  array([116, 668,  73, 210]),
#  array([364, 641,  87, 225]),
#  array([516, 655, 287, 199]),
#  array([827, 671, 102, 210]),
#  array([825, 666, 105, 212]),
#  array([1034,  649,  161,  302]),
#  array([1036,  649,  155,  302]),
#  array([1221,  686,  114,  204]),
#  array([1223,  681,  110,  211]),
#  array([1616,  709,   90,   76]),
#  array([366, 762, 381, 191]),
#  array([387, 762, 358, 188]),
#  array([1037,  650,  155,  306]),
#  array([1249,  751,  310,  206]),
#  array([1252,  747,  309,  207]),
#  array([1434,  780,  459,  178]),
#  array([158, 810, 576, 150]),
#  array([361, 770, 375, 173]),
#  array([1249,  755,  306,  202]),
#  array([1426,  779,  472,  179]),
#  array([1429,  778,  490,  184]),
#  array([760, 349, 199,  99]),
#  array([1012,  338,  261,  205]),
#  array([622, 403, 137, 119]),
#  array([873, 418, 113, 111]),
#  array([1014,  333,  269,  213]),
#  array([1018,  341,  262,  212]),
#  array([642, 417, 125, 119]),
#  array([667, 463, 140, 124]),
#  array([771, 447, 138, 107]),
#  array([873, 420, 113, 104]),
#  array([668, 472, 135, 116]),
#  array([1209,  449,  342,  304]),
#  array([1206,  449,  345,  307]),
#  array([1577,  571,  255,  114]),
#  array([1206,  457,  333,  302]),
#  array([1584,  581,  257,  116]),
#  array([1593,  578,  247,  120]),
#  array([186, 615,  83, 228]),
#  array([287, 624,  65, 177]),
#  array([289, 618,  59, 180]),
#  array([947, 648, 179, 176]),
#  array([117, 665,  80, 195]),
#  array([176, 617,  87, 234]),
#  array([188, 616,  78, 221]),
#  array([285, 624,  65, 178]),
#  array([363, 654,  76, 197]),
#  array([366, 645,  82, 206]),
#  array([377, 655,  71, 187]),
#  array([522, 659, 278, 196]),
#  array([524, 651, 272, 209]),
#  array([829, 667, 100, 206]),
#  array([951, 653, 182, 169]),
#  array([959, 647, 185, 177]),
#  array([1224,  685,  108,  172]),
#  array([1709,  679,  126,  113]),
#  array([1704,  673,  132,  124]),
#  array([120, 681,  68, 198]),
#  array([117, 676,  68, 193]),
#  array([365, 647,  81, 213]),
#  array([518, 659, 283, 185]),
#  array([827, 677, 101, 197]),
#  array([826, 673, 102, 199]),
#  array([1037,  656,  156,  282]),
#  array([1039,  655,  151,  287]),
#  array([1223,  691,  112,  191]),
#  array([1225,  687,  106,  193]),
#  array([364, 770, 381, 178]),
#  array([387, 769, 352, 184]),
#  array([1041,  657,  148,  291]),
#  array([1248,  763,  309,  192]),
#  array([1251,  755,  305,  198]),
#  array([1434,  787,  458,  163]),
#  array([223, 789, 539, 163]),
#  array([361, 775, 376, 164]),
#  array([1252,  762,  301,  193]),
#  array([1424,  790,  475,  162]),
#  array([1430,  792,  483,  164]),
#  array([752, 342, 195, 107]),
#  array([614, 393, 150, 125]),
#  array([619, 398, 145, 121]),
#  array([857, 391, 141, 136]),
#  array([863, 401, 131, 130]),
#  array([1014,  320,  272,  240]),
#  array([1017,  330,  271,  232]),
#  array([653, 443, 151, 134]),
#  array([654, 453, 217, 125]),
#  array([846, 418, 142, 115]),
#  array([1213,  435,  341,  333]),
#  array([660, 486, 142, 111]),
#  array([1206,  439,  345,  327]),
#  array([1206,  439,  347,  328]),
#  array([1571,  565,  265,  130]),
#  array([1579,  570,  265,  126]),
#  array([519, 647, 284, 205]),
#  array([523, 646, 279, 206]),
#  array([818, 664, 107, 211]),
#  array([947, 642, 190, 187]),
#  array([971, 639, 212, 252]),
#  array([1212,  688,  123,  200]),
#  array([1713,  679,  125,  120]),
#  array([325, 767, 428, 186]),
#  array([482, 666, 306, 219]),
#  array([823, 684, 109, 193]),
#  array([822, 673, 101, 206]),
#  array([957, 642, 182, 196]),
#  array([1036,  662,  154,  282]),
#  array([1043,  655,  176,  295]),
#  array([1245,  750,  309,  200]),
#  array([1256,  746,  317,  206]),
#  array([1437,  772,  480,  180]),
#  array([1718,  678,  125,  130]),
#  array([161, 785, 583, 172]),
#  array([344, 763, 394, 189]),
#  array([1251,  755,  304,  200]),
#  array([1439,  775,  473,  178]),
#  array([1009,  325,  285,  234]),
#  array([1007,  332,  289,  224]),
#  array([1197,  438,  361,  324]),
#  array([1197,  437,  362,  330]),
#  array([1200,  444,  362,  320]),
#  array([521, 653, 278, 204]),
#  array([525, 650, 269, 205]),
#  array([949, 641, 184, 191]),
#  array([977, 645, 212, 248]),
#  array([329, 772, 418, 185]),
#  array([476, 670, 311, 222]),
#  array([965, 646, 172, 197]),
#  array([1034,  661,  157,  280]),
#  array([1042,  661,  173,  285]),
#  array([1246,  751,  301,  196]),
#  array([1257,  755,  313,  198]),
#  array([1441,  776,  477,  174]),
#  array([342, 768, 399, 188]),
#  array([1253,  760,  296,  192]),
#  array([1443,  781,  465,  179]),
#  array([1210,  439,  331,  330]),
#  array([1211,  443,  332,  338]),
#  array([1209,  450,  337,  312])]

# %%
classes
# Out:
# [np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(19),
#  np.int64(19)]

# %%
boxes_np = np.array(boxes).tolist()
confidences_np = np.array(confidences).tolist()


#NMS
index = cv2.dnn.NMSBoxes(boxes_np, confidences_np,0.25,0.45).flatten()

# %%
len(index) # this are objects with good probability score
# Out:
# 24

# %%
# Draw Bounding Box

for ind in index:
    x,y,w,h = boxes_np[ind]
    bb_conf = confidences_np[ind]
    classes_id = classes[ind]
    class_name = labels[classes_id]

    text = f'{class_name}: {bb_conf}%'
    print(text)
# Out:
# bus: 0.8844749331474304%
# car: 0.8822808265686035%
# car: 0.8250964879989624%
# person: 0.8225795030593872%
# car: 0.8217966556549072%
# car: 0.802025318145752%
# person: 0.7973363995552063%
# car: 0.7738236784934998%
# person: 0.7716341018676758%
# car: 0.7705860137939453%
# car: 0.7690921425819397%
# car: 0.7572552561759949%
# person: 0.7387762069702148%
# car: 0.7386461496353149%
# person: 0.7318008542060852%
# car: 0.7315365672111511%
# person: 0.7075316309928894%
# person: 0.6955419182777405%
# car: 0.6704357266426086%
# person: 0.6613653898239136%
# car: 0.6357400417327881%
# person: 0.6228829622268677%
# person: 0.5696365237236023%
# person: 0.5396284461021423%

# %%
cv2.rectangle(image, (x,y),(x+w,y+w),(0,255,0),2)
cv2.rectangle(image,(x,y-30),(x+w,y),(0,255,255),-1)

cv2.putText(image,text,(x,y-10),cv2.FONT_HERSHEY_PLAIN,0.7,(0,0,0),1)
# Out:
# array([[[10, 17, 14],
#         [11, 18, 15],
#         [11, 18, 15],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]],
#
#        [[10, 17, 14],
#         [10, 17, 14],
#         [11, 18, 15],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]],
#
#        [[10, 17, 14],
#         [10, 17, 14],
#         [10, 17, 14],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]],
#
#        ...,
#
#        [[33, 42, 52],
#         [34, 43, 52],
#         [33, 42, 51],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]],
#
#        [[51, 60, 73],
#         [51, 61, 71],
#         [49, 59, 69],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]],
#
#        [[64, 76, 88],
#         [63, 75, 87],
#         [63, 73, 83],
#         ...,
#         [ 9, 13, 14],
#         [ 9, 13, 14],
#         [ 9, 13, 14]]], dtype=uint8)

# %%
cv2.imshow('original',img)
cv2.imshow('yolo_prediction',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
